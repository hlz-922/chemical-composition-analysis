# %% [markdown]
# # Archaeological objects and their chemical composition
#
# During recent survey of an archaeological site in East Africa called Kilwa, researchers found huge volumes of iron slag. This is a material that forms as a byproduct during iron production and is usually discarded.
#
# Following preliminary examination, archaeologists proposed a hypothesis that two different steps of the production process were taking place at the site.
#
# In order to test this hypothesis, samples of iron slag were collected and analysed to obtain information about their chemical composition. Different technological processes lead to iron slag having distinct chemical compositions.
#
# The goal of this project is to carry out principal component analysis of the chemical information to determine whether the archaeologists are right. The analysis should reveal whether one, two, or more distinct clusters are visible in the PCA plot.

# %% [markdown]
# KATE expects your code to define variables with specific names that correspond to certain things we are interested in.
#
# KATE will run your notebook from top to bottom and check the latest value of those variables, so make sure you don't overwrite them.
#
# * Remember to uncomment the line assigning the variable to your answer and don't change the variable or function names.
# * Use copies of the original or previous DataFrames to make sure you do not overwrite them by mistake.
#
# You will find instructions below about how to define each variable.
#
# Once you're happy with your code, upload your notebook to KATE to check your feedback.

# %% [markdown]
# ## Data loading and cleaning

# %% [markdown]
# First, let's import the necessary packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /var/folders/00/h4l_zl594z1g4kp3qw9d3bdc0000gn/T/ipykernel_32457/555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# **Q1. Use `pandas` to load the `kilwa_site_data.csv` dataset (found in the data/ folder) into a DataFrame, and look at the first 10 rows. Store the dataset under variable `data`**.

# %%
# Your code here...
data = pd.read_csv('data/kilwa_site_data.csv')
data.head(10)
# Out:
#   Sample   Site   Sodium        Oxygen  Magnesium  Potassium   Calcium  \
# 0  EB005  Kilwa  1.20768  1.600000e-06   0.094387   0.000000  3.134449
# 1  EB005  Kilwa  0.00000  7.140000e-08   0.077279   0.112684  1.701345
# 2  EB005  Kilwa  0.00000 -1.300000e-06   0.166517   0.261423  2.038331
# 3  EB005  Kilwa  0.00000  3.850000e-07   0.111906   0.164109  1.555043
# 4  EB005  Kilwa  0.00000 -1.190000e-06   0.107345   0.443995  2.773370
# 5  EB005  Kilwa  0.00000  4.630000e-09   0.118816   0.434789  3.875111
# 6  EB005  Kilwa  0.00000  5.280000e-08   0.071439   0.341861  4.396350
# 7  EB005  Kilwa  0.00000 -1.620000e-06   0.215417   0.318849  5.331294
# 8  EB005  Kilwa  0.00000  2.440000e-06   0.373711   0.212581  6.600972
# 9  EB005  Kilwa  0.00000 -3.170000e-06   0.040159   0.510632  3.579475
#
#    Titanium       Iron  Aluminium  ...  Strontium    Copper    Nickel  \
# 0  0.176351  74.210419   1.834800  ...   0.027355  0.000713  0.006769
# 1  0.150296  78.902044   1.338994  ...   0.017984  0.000000  0.000000
# 2  0.124420  76.549931   1.498002  ...   0.026264  0.000000  0.000000
# 3  0.175369  77.464105   1.222445  ...   0.019069  0.023835  0.000000
# 4  0.160835  75.382715   2.178886  ...   0.033115  0.024863  0.000000
# 5  0.188014  74.482809   2.382049  ...   0.056796  0.007780  0.000000
# 6  0.120509  73.690668   1.545310  ...   0.039254  0.020437  0.002422
# 7  0.120079  70.587479   1.551726  ...   0.038013  0.000392  0.000000
# 8  0.101754  65.099005   1.360731  ...   0.031939  0.003489  0.000000
# 9  0.249242  75.850214   2.547156  ...   0.055364  0.008966  0.000000
#
#      Sulfur  Phosphorus  Rhodium      Tin  Chromium  Arsenic  Zinc
# 0  0.807874    0.867509        0  0.00000       0.0      0.0   0.0
# 1  0.031357    0.042061        0  0.00000       0.0      0.0   0.0
# 2  0.038252    0.065478        0  0.00000       0.0      0.0   0.0
# 3  0.004183    0.044562        0  0.00000       0.0      0.0   0.0
# 4  0.064500    0.040204        0  0.02025       0.0      0.0   0.0
# 5  0.035393    0.090572        0  0.00000       0.0      0.0   0.0
# 6  0.054152    0.046076        0  0.00000       0.0      0.0   0.0
# 7  0.034409    0.051757        0  0.00000       0.0      0.0   0.0
# 8  0.225348    0.387406        0  0.00000       0.0      0.0   0.0
# 9  0.050464    0.107273        0  0.00000       0.0      0.0   0.0
#
# [10 rows x 27 columns]

# %% [markdown]
# You will notice that the first two columns contain information about the sample and the site the objects were found at. The remaining rows contain quantitative elemental information about the samples. Let's start by inspecting the dataset. Look at the `.info()` of the dataset to see if there are any null values.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sample      149 non-null    object
#  1   Site        149 non-null    object
#  2   Sodium      149 non-null    float64
#  3   Oxygen      149 non-null    float64
#  4   Magnesium   149 non-null    float64
#  5   Potassium   149 non-null    float64
#  6   Calcium     149 non-null    float64
#  7   Titanium    149 non-null    float64
#  8   Iron        149 non-null    float64
#  9   Aluminium   149 non-null    float64
#  10  Silicon     149 non-null    float64
#  11  Lead        149 non-null    float64
#  12  Manganese   149 non-null    float64
#  13  Chlorine    149 non-null    float64
#  14  Silver      149 non-null    float64
#  15  Gold        149 non-null    float64
#  16  Barium      149 non-null    float64
#  17  Strontium   149 non-null    float64
#  18  Copper      149 non-null    float64
#  19  Nickel      149 non-null    float64
#  20  Sulfur      149 non-null    float64
#  21  Phosphorus  149 non-null    float64
#  22  Rhodium     149 non-null    int64
#  23  Tin         149 non-null    float64
#  24  Chromium    149 non-null    float64
#  25  Arsenic     149 non-null    float64
#  26  Zinc        149 non-null    float64
# dtypes: float64(24), int64(1), object(2)
# memory usage: 31.6+ KB

# %% [markdown]
# **Q2. Store the first column, containing sample information, as a `pandas Series` type variable called `sample_list`.**
#
#
# _Hint: You can check the datatype of a variable by using the in-built python function `type()`, e.g. `type(sample_list)`. The precise datatype of a `pandas Series` is `pandas.core.series.Series`._

# %%
# Your code here...
sample_list = data['Sample']
type(sample_list)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Q3. Further cleaning**
#
# * Make a copy of `data` called `cleaned_data` using the `.copy()` method.
# * Drop any non-numeric columns from `cleaned_data`.
# * Remove any columns that contain only zeros from `cleaned_data`, as these contain no valuable information.
#
# _Hint: You may find the [`pandas` function `.any()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.any.html) useful for removing columns containing only zeros._

# %%
# Your code here...
cleaned_data = data.copy()
cleaned_data = cleaned_data.select_dtypes(include=['number'])
cleaned_data = cleaned_data.loc[:, (cleaned_data != 0).any(axis=0)]

# %% [markdown]
# ## PCA

# %% [markdown]
# Let's make sure we have the necessary packages for PCA.
# Import `preprocessing` from `sklearn`, and `PCA` from `sklearn.decomposition`.

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %% [markdown]
# **Q4. Before doing the PCA, centre and scale `cleaned_data` using [`preprocessing.scale()`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.scale.html). Store the scaled data as `scaled_data`.**

# %%
# Your code here...
scaled_data = preprocessing.scale(cleaned_data)

# %% [markdown]
# **Q5. Instantiate a `PCA` object with the variable name `pca`, and fit it to `scaled_data`.**

# %%
# Your code here...
pca = PCA()

pca.fit(scaled_data)
# Out:
# PCA()

# %% [markdown]
# **Q6. How much variance do the first two components explain? Calculate the sum of the `pca.explained_variance_ratio_` for the first two components and store the result as `expl_var`.**

# %%
type(scaled_data)
# Out:
# numpy.ndarray

# %%
pca.explained_variance_ratio_
# Out:
# array([3.87585976e-01, 7.74857945e-02, 6.62212457e-02, 6.27403221e-02,
#        5.92357958e-02, 4.89691159e-02, 4.31253903e-02, 3.77962094e-02,
#        3.37584247e-02, 3.25976458e-02, 2.88533641e-02, 2.44790976e-02,
#        2.09320748e-02, 1.97494250e-02, 1.52773355e-02, 1.14914840e-02,
#        9.54294725e-03, 8.06654312e-03, 5.26872200e-03, 3.56126747e-03,
#        2.37259660e-03, 8.89222017e-04, 9.03015738e-21])

# %%
# Your code here...
expl_var = sum(pca.explained_variance_ratio_[:2])
expl_var
# Out:
# 0.46507177067197925

# %% [markdown]
# **Q7. Transform the `scaled_data` and store the outcome as `pca_data`.**

# %%
scaled_data.shape
# Out:
# (149, 23)

# %%
# Your code here...
pca_data = pca.transform(scaled_data)
pca_data.shape
# Out:
# (149, 23)

# %% [markdown]
# **Q8. Create a `pd.DataFrame` of `pca_data` setting its index as `sample_list` which we stored earlier. Save this DataFrame as `pca_df`.**

# %%
# Your code here...
pca_df = pd.DataFrame(pca_data, index=sample_list)

# %% [markdown]
# Take a look at `pca_df` by running the cell below. Each column of the DataFrame is the number of a principal component.

# %%
pca_df.head(5)
# Out:
#               0         1         2         3         4         5         6   \
# Sample
# EB005   3.495169  0.243190  0.784297  3.942873 -3.310697  6.284095 -1.464852
# EB005   5.284807  0.868301 -1.365226 -1.344089  0.223755 -0.188567 -1.153522
# EB005   5.201163  1.080906 -1.008327 -0.233257  0.223904 -1.146125 -1.139293
# EB005   5.772982  0.297227  0.958711  1.758177  0.160960 -1.618158 -1.683819
# EB005   5.399076 -0.515954  1.542551  1.284042  1.672614 -2.046590 -0.689911
#
#               7         8         9   ...        13        14        15  \
# Sample                                ...
# EB005  -0.639260  1.890832  1.126820  ... -0.453668 -0.351047 -0.488436
# EB005  -0.800614  0.703087 -0.468624  ...  1.168025  0.015413 -0.274737
# EB005  -1.144187  2.015506 -0.974662  ...  1.097785  0.200440 -0.595642
# EB005   0.181453  0.019367 -1.102307  ... -0.503443 -0.459347 -1.153361
# EB005   0.035442  1.298997  2.464619  ...  2.398021  0.575657  0.448360
#
#               16        17        18        19        20        21  \
# Sample
# EB005   0.015330 -0.195698  0.300550  0.517711  0.121189  0.009691
# EB005   0.290979 -0.162386 -0.359746  0.134857 -0.325408  0.078026
# EB005   0.222648 -0.203020 -0.616121 -0.083985 -0.227360 -0.042062
# EB005   0.092350  0.338901 -0.262732  0.006916 -0.433056 -0.064944
# EB005   0.094074 -0.191027 -0.631509 -0.337904 -0.015380  0.003414
#
#                   22
# Sample
# EB005  -1.819367e-10
# EB005  -7.680361e-11
# EB005   2.181439e-10
# EB005  -2.214635e-10
# EB005   8.240018e-10
#
# [5 rows x 23 columns]

# %% [markdown]
# **Q9. Make a copy of `pca_df` named `pca_table` using `.copy()`, and rename the columns of `pca_table`, adding 'PC' to the beginning of each column name (`['PC1', 'PC2', 'PC3', 'PC4', 'PC5'...]`).**

# %%
# Your code here...
pca_table = pca_df.copy()
pca_table.columns = [f"PC{i}" for i in range(1, pca_table.shape[1] + 1)]

# %% [markdown]
# ## Plotting

# %% [markdown]
# Run the cell below to create a colour palette to be used for plotting.

# %%
ID_palette = {}
for i in np.unique(pca_table.index):
    if i in ['EB005', 'EB009', 'EB023', 'EB036']:
        ID_palette[i] = "#A5C93D"  
    else:
        ID_palette[i] = "#8B006B"
ID_palette
# Out:
# {'EB005': '#A5C93D',
#  'EB008': '#8B006B',
#  'EB009': '#A5C93D',
#  'EB017': '#8B006B',
#  'EB018': '#8B006B',
#  'EB023': '#A5C93D',
#  'EB028': '#8B006B',
#  'EB030': '#8B006B',
#  'EB033': '#8B006B',
#  'EB034': '#8B006B',
#  'EB035': '#8B006B',
#  'EB036': '#A5C93D',
#  'EB037': '#8B006B',
#  'EB038': '#8B006B',
#  'EB040': '#8B006B'}

# %% [markdown]
# **Q10. Use `seaborn` to plot the first _two_ principal components in a scatterplot.**
#
# - Set `hue` to `pca_table.index`
# - Set `palette` to `ID_palette`
# - Plot both directions of the PCA. Since `data` was `pca.transform`ed from data axes to principal axes, PCA directions correspond to coordinate axes.
#
# In other words, add a horizontal line, passing through `0, 0` that extends the full width of the graph, and a vertical line, passing through `0, 0`, that extends the full height of the graph.
#
# _Hint: Use the `matplotlib.pyplot` (which we imported earlier as `plt`) [`.plot()` method](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html) to draw these additional lines._

# %%
# Your code here...
sns.scatterplot(x='PC1', y='PC2', data=pca_table, hue=pca_table.index, palette=ID_palette)

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.5)
plt.axvline(x=0, color='black', linestyle='--', linewidth=0.5)


plt.title('PCA Scatterplot')
plt.xlabel('PC1')
plt.ylabel('PC2')

plt.show()

# %% [markdown]
# ## PCA and plotting of transposed data

# %% [markdown]
# In archaeological science it is common practice to transpose the dataset and perform PCA with elements set as the index. In other words, rather than have a row per sample and a column for each element, it is preferred to have a row per element and a column for each sample.

# %% [markdown]
# **Q11. Transpose the `cleaned_data` and store this converted dataset as `transposed_data`.**

# %%
# Your code here...
# Lead         0.009186   0.005883   0.001331  6.347730e-03   0.007521
# Manganese    0.921086   0.897416   0.911791  9.360062e-01   0.886475
# Chlorine     0.000000   0.007599   0.058299  5.733011e-02   0.008729
# Gold         0.011413   0.000000   0.001279  1.183941e-02   0.000383
# Barium       0.000000   0.026141   0.014913  3.974557e-03   0.015741
# Strontium    0.063831   0.069963   0.056812  6.207239e-02   0.058996
# Copper       0.004527   0.003605   0.006201  6.776396e-03   0.000218
# Nickel       0.000000   0.000000   0.000000  0.000000e+00   0.000000
# Sulfur       0.093954   0.060270   0.109180  1.545638e-01   0.082912
# Phosphorus   2.232018   2.510589   2.007152  2.304024e+00   2.073475
# Tin          0.000000   0.000000   0.000000  0.000000e+00   0.000000
# Chromium     0.000000   0.000000   0.000000  0.000000e+00   0.000000
# Arsenic      0.000000   0.000000   0.000000  0.000000e+00   0.000000
# Zinc         0.000000   0.000000   0.000000  0.000000e+00   0.000000
#
# [23 rows x 149 columns]

# %% [markdown]
# **Q12. Based on the code you wrote earlier, create a function called `PCA_transformed_table` that:**
#
#
# * Takes a dataset as an argument
# * Scales the dataset
# * Instantiates a PCA model
# * Fits and transforms the scaled dataset
# * Converts the fitted and transformed dataset to a `pd.DataFrame` using the index of the supplied dataset as the index
# * Renames the columns from 0, 1, 2... to PC1, PC2, PC3...
# * Returns this processed DataFrame.
#
# Call the `PCA_transformed_table` function supplying `transposed_data` as an argument and storing the returned `pd.DataFrame` as `t_pca_table`.

# %%
# Your code here...
def PCA_transformed_table(data):
    scaled_data = preprocessing.scale(data)
    pca = PCA()
    pca_data = pca.fit_transform(scaled_data)
    pca_df = pd.DataFrame(pca_data, index=data.index)
    pca_df.columns = [f"PC{i}" for i in range(1, pca_df.shape[1] + 1)]
    return pca_df
    
t_pca_table = PCA_transformed_table(transposed_data)
t_pca_table
# Out:
#                   PC1       PC2       PC3       PC4       PC5       PC6  \
# Sodium      -3.798708 -0.310886 -0.064019 -0.050880 -0.023722 -0.061485
# Oxygen      -4.158375 -0.478518 -0.183171  0.018589 -0.018754 -0.010990
# Magnesium   -2.934965 -0.091243  0.180767 -0.000148  0.201685  0.310606
# Potassium   -3.230258 -0.067637  0.029967 -0.012213 -0.062530 -0.018324
# Calcium      1.728540  1.415378  1.433612  0.733164 -0.036532 -0.024586
# Titanium    -3.844446 -0.377511 -0.135716 -0.004517 -0.017388 -0.006631
# Iron        52.569658 -2.735674  0.046555 -0.021082 -0.002126 -0.000283
# Aluminium    1.484457  1.878841  1.215450 -0.681734 -0.160797  0.032406
# Silicon     17.546231  6.278389 -0.880225  0.056708  0.020322 -0.004570
# Lead        -4.151069 -0.479510 -0.183994  0.020787 -0.018780 -0.012021
# Manganese   -3.387420 -0.106877  0.010837 -0.034009 -0.012548  0.113404
# Chlorine    -4.145481 -0.475935 -0.185107  0.015225 -0.012157 -0.016262
# Copper      2.040654e-04  8.075702e-05  9.191593e-05 -8.807274e-06
# Nickel     -1.653773e-03 -1.578870e-03 -8.422972e-04 -1.249406e-05
# Sulfur      6.373888e-06 -1.214691e-06  2.787629e-06 -1.717655e-07
# Phosphorus  8.573557e-07 -2.348116e-06  8.806203e-07 -1.854055e-08
# Tin         2.688754e-03 -1.691260e-04 -3.358968e-04 -9.892588e-06
# Chromium    3.031876e-04 -1.945157e-04 -7.420997e-05  1.967604e-05
# Arsenic    -6.165880e-04  1.239906e-04  1.069154e-03 -3.727199e-04
# Zinc       -8.629437e-04  2.046812e-03 -7.897302e-04 -9.561358e-06
#
#                     PC23
# Sodium      5.794524e-16
# Oxygen      5.794524e-16
# Magnesium   5.794524e-16
# Potassium   5.794524e-16
# Calcium     5.794524e-16
# Titanium    5.794524e-16
# Iron        5.794524e-16
# Aluminium   5.794524e-16
# Silicon     5.794524e-16
# Lead        5.794524e-16
# Manganese   5.794524e-16
# Chlorine    5.794524e-16
# Gold        5.794524e-16
# Barium      5.794524e-16
# Strontium   5.794524e-16
# Copper      5.794524e-16
# Nickel      5.794524e-16
# Sulfur      5.794524e-16
# Phosphorus  5.794524e-16
# Tin         5.794524e-16
# Chromium    5.794524e-16
# Arsenic     5.794524e-16
# Zinc        5.794524e-16
#
# [23 rows x 23 columns]

# %% [markdown]
# **Q13. Use `seaborn` to plot the first _two_ principal components in a scatterplot.**
#
#
# * Plot both PCA directions.
#     - As before, this means a horizontal line passing through `0, 0`, and a vertical line passing through `0, 0`.
# * Annotate each point by index (the element name). You may find [this link](https://python-graph-gallery.com/46-add-text-annotation-on-scatterplot/) useful.

# %%
sns.scatterplot(x=t_pca_table['PC1'], y=t_pca_table['PC2'], color='blue')

# Draw horizontal and vertical lines passing through (0,0)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.5)
plt.axvline(x=0, color='black', linestyle='--', linewidth=0.5)

# Annotate each point by index
for i, txt in enumerate(t_pca_table.index):
    plt.annotate(txt, (t_pca_table['PC1'][i], t_pca_table['PC2'][i]))

# Set plot title and labels
plt.title('PCA Scatterplot')
plt.xlabel('PC1')
plt.ylabel('PC2')

# Show plot
plt.show()
# Out:
# /var/folders/00/h4l_zl594z1g4kp3qw9d3bdc0000gn/T/ipykernel_32457/3893794163.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(txt, (t_pca_table['PC1'][i], t_pca_table['PC2'][i]))

# %% [markdown]
# Which two elements stand out?

# %% [markdown]
# **Q14. Assign the names of the elements corresponding to the maximum values of PC1 and PC2 to a variable called `max_values`.**
#
# This should be a `tuple` of the form `(<PC1 max value element>, <PC2 max value element>)`.

# %%
# Your code here...
# max_values = 

# Find the index corresponding to the maximum value of PC1 and PC2
max_pc1_index = t_pca_table['PC1'].idxmax()
max_pc2_index = t_pca_table['PC2'].idxmax()

# Get the element names corresponding to the maximum values of PC1 and PC2
max_pc1_element = max_pc1_index
max_pc2_element = max_pc2_index

# Assign the names to the variable max_values as a tuple
max_values = (max_pc1_element, max_pc2_element)
